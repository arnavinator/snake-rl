# %%
import pandas as pd 
import pickle
import re
import matplotlib.pyplot as plt

# %%
with open('./results_1p5.pkl', 'rb') as file:
    results_dict = pickle.load(file)

# %%
df = pd.DataFrame()
for test, test_res in results_dict.items():
  temp_df = pd.DataFrame([test_res], index=[test])
  df = pd.concat([df, temp_df])

# %%
df
# Out:
#                                                     Total Number of Frames  \
# Agent(MAX_MEMORY=5000, BATCH_SIZE=500, ALPHA=0....                  126791
# Agent(MAX_MEMORY=5000, BATCH_SIZE=500, ALPHA=0....                  149202
# Agent(MAX_MEMORY=5000, BATCH_SIZE=500, ALPHA=0....                  100617
# Agent(MAX_MEMORY=5000, BATCH_SIZE=500, ALPHA=0....                  133465
# Agent(MAX_MEMORY=5000, BATCH_SIZE=500, ALPHA=0....                  102231
# ...                                                                    ...
# Agent(MAX_MEMORY=10000, BATCH_SIZE=1000, ALPHA=...                  112156
# Agent(MAX_MEMORY=10000, BATCH_SIZE=1000, ALPHA=...                  101027
# Agent(MAX_MEMORY=10000, BATCH_SIZE=1000, ALPHA=...                  108459
# Agent(MAX_MEMORY=10000, BATCH_SIZE=1000, ALPHA=...                  100598
# Agent(MAX_MEMORY=10000, BATCH_SIZE=1000, ALPHA=...                  110753
#
#                                                     Total Number of Games  \
# Agent(MAX_MEMORY=5000, BATCH_SIZE=500, ALPHA=0....                    120
# Agent(MAX_MEMORY=5000, BATCH_SIZE=500, ALPHA=0....                    120
# Agent(MAX_MEMORY=5000, BATCH_SIZE=500, ALPHA=0....                    120
# Agent(MAX_MEMORY=5000, BATCH_SIZE=500, ALPHA=0....                    120
# Agent(MAX_MEMORY=5000, BATCH_SIZE=500, ALPHA=0....                    120
# ...                                                                   ...
# Agent(MAX_MEMORY=10000, BATCH_SIZE=1000, ALPHA=...                    120
# Agent(MAX_MEMORY=10000, BATCH_SIZE=1000, ALPHA=...                    120
# Agent(MAX_MEMORY=10000, BATCH_SIZE=1000, ALPHA=...                    120
# Agent(MAX_MEMORY=10000, BATCH_SIZE=1000, ALPHA=...                    120
# Agent(MAX_MEMORY=10000, BATCH_SIZE=1000, ALPHA=...                    120
#
#                                                     Record Length  \
# Agent(MAX_MEMORY=5000, BATCH_SIZE=500, ALPHA=0....             73
# Agent(MAX_MEMORY=5000, BATCH_SIZE=500, ALPHA=0....             92
# Agent(MAX_MEMORY=5000, BATCH_SIZE=500, ALPHA=0....             80
# Agent(MAX_MEMORY=5000, BATCH_SIZE=500, ALPHA=0....             82
# Agent(MAX_MEMORY=5000, BATCH_SIZE=500, ALPHA=0....             60
# ...                                                           ...
# Agent(MAX_MEMORY=10000, BATCH_SIZE=1000, ALPHA=...             76
# Agent(MAX_MEMORY=10000, BATCH_SIZE=1000, ALPHA=...             78
# Agent(MAX_MEMORY=10000, BATCH_SIZE=1000, ALPHA=...             82
# Agent(MAX_MEMORY=10000, BATCH_SIZE=1000, ALPHA=...             70
# Agent(MAX_MEMORY=10000, BATCH_SIZE=1000, ALPHA=...             85
#
#                                                     Average Score across Games  \
# Agent(MAX_MEMORY=5000, BATCH_SIZE=500, ALPHA=0....                   36.558333
# Agent(MAX_MEMORY=5000, BATCH_SIZE=500, ALPHA=0....                   40.550000
# Agent(MAX_MEMORY=5000, BATCH_SIZE=500, ALPHA=0....                   31.566667
# Agent(MAX_MEMORY=5000, BATCH_SIZE=500, ALPHA=0....                   35.791667
# Agent(MAX_MEMORY=5000, BATCH_SIZE=500, ALPHA=0....                   30.541667
# ...                                                                        ...
# Agent(MAX_MEMORY=10000, BATCH_SIZE=1000, ALPHA=...                   32.325000
# Agent(MAX_MEMORY=10000, BATCH_SIZE=1000, ALPHA=...                   28.316667
# Agent(MAX_MEMORY=10000, BATCH_SIZE=1000, ALPHA=...                   34.641667
# Agent(MAX_MEMORY=10000, BATCH_SIZE=1000, ALPHA=...                   31.400000
# Agent(MAX_MEMORY=10000, BATCH_SIZE=1000, ALPHA=...                   33.050000
#
#                                                     Mean(Last 20 Games Length)  \
# Agent(MAX_MEMORY=5000, BATCH_SIZE=500, ALPHA=0....                       47.30
# Agent(MAX_MEMORY=5000, BATCH_SIZE=500, ALPHA=0....                       55.25
# Agent(MAX_MEMORY=5000, BATCH_SIZE=500, ALPHA=0....                       43.00
# Agent(MAX_MEMORY=5000, BATCH_SIZE=500, ALPHA=0....                       54.45
# Agent(MAX_MEMORY=5000, BATCH_SIZE=500, ALPHA=0....                       36.15
# ...                                                                        ...
# Agent(MAX_MEMORY=10000, BATCH_SIZE=1000, ALPHA=...                       40.95
# Agent(MAX_MEMORY=10000, BATCH_SIZE=1000, ALPHA=...                       37.05
# Agent(MAX_MEMORY=10000, BATCH_SIZE=1000, ALPHA=...                       47.75
# Agent(MAX_MEMORY=10000, BATCH_SIZE=1000, ALPHA=...                       37.40
# Agent(MAX_MEMORY=10000, BATCH_SIZE=1000, ALPHA=...                       47.05
#
#                                                     Stdev(Last 20 Games Length)  \
# Agent(MAX_MEMORY=5000, BATCH_SIZE=500, ALPHA=0....                    13.476275
# Agent(MAX_MEMORY=5000, BATCH_SIZE=500, ALPHA=0....                    15.661657
# Agent(MAX_MEMORY=5000, BATCH_SIZE=500, ALPHA=0....                    15.385058
# Agent(MAX_MEMORY=5000, BATCH_SIZE=500, ALPHA=0....                    16.353822
# Agent(MAX_MEMORY=5000, BATCH_SIZE=500, ALPHA=0....                     9.561773
# ...                                                                         ...
# Agent(MAX_MEMORY=10000, BATCH_SIZE=1000, ALPHA=...                    15.528925
# Agent(MAX_MEMORY=10000, BATCH_SIZE=1000, ALPHA=...                    12.043567
# Agent(MAX_MEMORY=10000, BATCH_SIZE=1000, ALPHA=...                    19.768346
# Agent(MAX_MEMORY=10000, BATCH_SIZE=1000, ALPHA=...                    10.066777
# Agent(MAX_MEMORY=10000, BATCH_SIZE=1000, ALPHA=...                    12.547809
#
#                                                     Mean(Efficiency Score(Last 20 Games Length))  \
# Agent(MAX_MEMORY=5000, BATCH_SIZE=500, ALPHA=0....                                      0.710854
# Agent(MAX_MEMORY=5000, BATCH_SIZE=500, ALPHA=0....                                      0.686820
# Agent(MAX_MEMORY=5000, BATCH_SIZE=500, ALPHA=0....                                      0.729730
# Agent(MAX_MEMORY=5000, BATCH_SIZE=500, ALPHA=0....                                      0.662996
# Agent(MAX_MEMORY=5000, BATCH_SIZE=500, ALPHA=0....                                      0.797651
# ...                                                                                          ...
# Agent(MAX_MEMORY=10000, BATCH_SIZE=1000, ALPHA=...                                      0.657044
# Agent(MAX_MEMORY=10000, BATCH_SIZE=1000, ALPHA=...                                      0.698027
# Agent(MAX_MEMORY=10000, BATCH_SIZE=1000, ALPHA=...                                      0.738247
# Agent(MAX_MEMORY=10000, BATCH_SIZE=1000, ALPHA=...                                      0.744509
# Agent(MAX_MEMORY=10000, BATCH_SIZE=1000, ALPHA=...                                      0.697952
#
#                                                     Stdev(Efficiency Score(Last 20 Games Length))
# Agent(MAX_MEMORY=5000, BATCH_SIZE=500, ALPHA=0....                                       0.053347
# Agent(MAX_MEMORY=5000, BATCH_SIZE=500, ALPHA=0....                                       0.080150
# Agent(MAX_MEMORY=5000, BATCH_SIZE=500, ALPHA=0....                                       0.063793
# Agent(MAX_MEMORY=5000, BATCH_SIZE=500, ALPHA=0....                                       0.074327
# Agent(MAX_MEMORY=5000, BATCH_SIZE=500, ALPHA=0....                                       0.070643
# ...                                                                                           ...
# Agent(MAX_MEMORY=10000, BATCH_SIZE=1000, ALPHA=...                                       0.071165
# Agent(MAX_MEMORY=10000, BATCH_SIZE=1000, ALPHA=...                                       0.087328
# Agent(MAX_MEMORY=10000, BATCH_SIZE=1000, ALPHA=...                                       0.054401
# Agent(MAX_MEMORY=10000, BATCH_SIZE=1000, ALPHA=...                                       0.051574
# Agent(MAX_MEMORY=10000, BATCH_SIZE=1000, ALPHA=...                                       0.058991
#
# [64 rows x 8 columns]

# %%
df = df.drop('Total Number of Games', axis=1)

# %% [markdown]
# ### Let's observe distribution of results

# %%
df.columns
# Out:
# Index(['Total Number of Frames', 'Record Length', 'Average Score across Games',
#        'Mean(Last 20 Games Length)', 'Stdev(Last 20 Games Length)',
#        'Mean(Efficiency Score(Last 20 Games Length))',
#        'Stdev(Efficiency Score(Last 20 Games Length))'],
#       dtype='object')

# %%
df.hist(bins=8, figsize=(20,30), layout=(4,2))
# Out:
# array([[<AxesSubplot: title={'center': 'Total Number of Frames'}>,
#         <AxesSubplot: title={'center': 'Record Length'}>],
#        [<AxesSubplot: title={'center': 'Average Score across Games'}>,
#         <AxesSubplot: title={'center': 'Mean(Last 20 Games Length)'}>],
#        [<AxesSubplot: title={'center': 'Stdev(Last 20 Games Length)'}>,
#         <AxesSubplot: title={'center': 'Mean(Efficiency Score(Last 20 Games Length))'}>],
#        [<AxesSubplot: title={'center': 'Stdev(Efficiency Score(Last 20 Games Length))'}>,
#         <AxesSubplot: >]], dtype=object)

# %%
df.mean()
# Out:
# Total Number of Frames                           111756.687500
# Record Length                                        74.984375
# Average Score across Games                           31.671484
# Mean(Last 20 Games Length)                           42.437500
# Stdev(Last 20 Games Length)                          14.042617
# Mean(Efficiency Score(Last 20 Games Length))          0.700055
# Stdev(Efficiency Score(Last 20 Games Length))         0.074567
# dtype: float64

# %% [markdown]
# Relative to Phase 1.0
# * we have average `Record Length` of 74 (as opposed to ~20 previously)
# * we have average `Mean(Last 20 Games Length)` of 42 (as opposed to ~10 previously)
# * training is a lot more stable now! we have many more "performant"
#     * however, the `Stdev(Last 20 Games Length)` of 14 is higher than ~8 from phase 1.0... from manual observation of runs, I belive this makes sense since the snake is able to achieve higher scores than before, but can still put itself in a loop before game over... this seems to be based on random placement of food relative to a sufficiently long snakes current positioning on the map
#         * based on the current design, there is no framework for the snake to know its about to enter a loop of killing itself, since can only see 1 block ahead and general direction of the food

# %% [markdown]
# ### Let's see if there are any particularly good parameters

# %%
# function to tell the param commonalities between a list of indices
def parse_agent_strings(agent_strings):
    # Initialize a defaultdict to store lists for each parameter
    params = defaultdict(list)

    # Regular expression to match key-value pairs in the format KEY=VALUE
    pattern = r'(\w+)=([\w\.\-]+)'

    for agent_string in agent_strings:
        # Find all key-value pairs in the current string
        matches = re.findall(pattern, agent_string)
        
        # For each key-value pair, store the value in the corresponding list
        for key, value in matches:
            if value.isdigit():
                params[key].append(int(value))
            else:
                try:
                    params[key].append(float(value))
                except ValueError:
                    # If the value is not a number, keep it as a string (e.g., True, False)
                    params[key].append(value)
    
    # Remove duplicates by converting lists to sets and back to lists
    return {key: list(set(values)) for key, values in params.items()}

  
# create histograms for parameters
def plot_agent_strings_params(agent_strings):
    # Initialize a defaultdict to store lists for each parameter
    params = defaultdict(list)

    # Regular expression to match key-value pairs in the format KEY=VALUE
    pattern = r'(\w+)=([\w\.\-]+)'

    # Iterate through each agent string
    for agent_string in agent_strings:
        # Find all key-value pairs in the current string
        matches = re.findall(pattern, agent_string)
        
        # For each key-value pair, store the value in the corresponding list
        for key, value in matches:
            # Convert numerical values to int or float if possible
            if value.isdigit():
                params[key].append(int(value))
            else:
                try:
                    params[key].append(float(value))
                except ValueError:
                    # If the value is not a number, keep it as a string (e.g., True, False)
                    params[key].append(value)
    
    # Now we'll go through each key and create a histogram
    for key, values in params.items():
        # Create a pandas Series from the values list
        values_series = pd.Series(values)
        
        # Get the value counts (frequency) for the values in this key
        value_counts = values_series.value_counts()
        
        # Plot the histogram (bar chart) for this key
        value_counts.plot(kind='bar', edgecolor='black')
        plt.title(f'Histogram of {key}')
        plt.xlabel(key)
        plt.ylabel('Count')
        plt.show()

# %%
filtered_df = filtered_df = df[(df['Record Length'] >= 70) &\
                 (df['Mean(Last 20 Games Length)'] >= 40) 
                ]

len(filtered_df)
# Out:
# 35

# %% [markdown]
# Whereas in Phase 1.0 we had 4/1944 (0.2%) meet the criteria above, in Phase 1.5 we have 35/64 (56%) meet this criteria
#
# Let's just filter by an extreme criteria to see there shared/different params

# %%
filtered_df = filtered_df = df[(df['Record Length'] >= 70) &\
                 (df['Mean(Last 20 Games Length)'] >= 50) 
                ]
print(len(filtered_df))
filtered_df
# Out:
# 3
#                                                     Total Number of Frames  \
# Agent(MAX_MEMORY=5000, BATCH_SIZE=500, ALPHA=0....                  149202
# Agent(MAX_MEMORY=5000, BATCH_SIZE=500, ALPHA=0....                  133465
# Agent(MAX_MEMORY=10000, BATCH_SIZE=500, ALPHA=0...                  143189
#
#                                                     Record Length  \
# Agent(MAX_MEMORY=5000, BATCH_SIZE=500, ALPHA=0....             92
# Agent(MAX_MEMORY=5000, BATCH_SIZE=500, ALPHA=0....             82
# Agent(MAX_MEMORY=10000, BATCH_SIZE=500, ALPHA=0...             86
#
#                                                     Average Score across Games  \
# Agent(MAX_MEMORY=5000, BATCH_SIZE=500, ALPHA=0....                   40.550000
# Agent(MAX_MEMORY=5000, BATCH_SIZE=500, ALPHA=0....                   35.791667
# Agent(MAX_MEMORY=10000, BATCH_SIZE=500, ALPHA=0...                   38.558333
#
#                                                     Mean(Last 20 Games Length)  \
# Agent(MAX_MEMORY=5000, BATCH_SIZE=500, ALPHA=0....                       55.25
# Agent(MAX_MEMORY=5000, BATCH_SIZE=500, ALPHA=0....                       54.45
# Agent(MAX_MEMORY=10000, BATCH_SIZE=500, ALPHA=0...                       50.65
#
#                                                     Stdev(Last 20 Games Length)  \
# Agent(MAX_MEMORY=5000, BATCH_SIZE=500, ALPHA=0....                    15.661657
# Agent(MAX_MEMORY=5000, BATCH_SIZE=500, ALPHA=0....                    16.353822
# Agent(MAX_MEMORY=10000, BATCH_SIZE=500, ALPHA=0...                    17.205450
#
#                                                     Mean(Efficiency Score(Last 20 Games Length))  \
# Agent(MAX_MEMORY=5000, BATCH_SIZE=500, ALPHA=0....                                      0.686820
# Agent(MAX_MEMORY=5000, BATCH_SIZE=500, ALPHA=0....                                      0.662996
# Agent(MAX_MEMORY=10000, BATCH_SIZE=500, ALPHA=0...                                      0.619096
#
#                                                     Stdev(Efficiency Score(Last 20 Games Length))
# Agent(MAX_MEMORY=5000, BATCH_SIZE=500, ALPHA=0....                                       0.080150
# Agent(MAX_MEMORY=5000, BATCH_SIZE=500, ALPHA=0....                                       0.074327
# Agent(MAX_MEMORY=10000, BATCH_SIZE=500, ALPHA=0...                                       0.061068

# %%
parse_agent_strings(filtered_df.index)
# Out:
# {'MAX_MEMORY': [5000, 10000],
#  'BATCH_SIZE': [500],
#  'ALPHA': [0.001],
#  'ALPHA_DECAY': ['True'],
#  'GAMMA': [0.7],
#  'EPSILON': [0.3],
#  'EPSILON_FLOOR': [0.0],
#  'EPSILON_LIN_DEC': ['False'],
#  'EPSILON_DEC_LIM': [80, 60],
#  'PRI_REPLAY_EN': ['True']}
